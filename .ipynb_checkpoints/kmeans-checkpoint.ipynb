# %%
import numpy as np
from matplotlib import pyplot as plt
import mglearn
import pandas as pd
data = pd.read_csv('DatosVPI_KAJA/DatosVPI/28Gbd_16QAM/D1_LW1K_LP100e-3/D1_LW1K_LP100e-3.csv')
data
# Out:
#               I         Q
# 0     -2.932604  0.767086
# 1      0.672889 -0.928540
# 2     -2.866267  2.783635
# 3      0.617238 -2.957566
# 4     -2.839210  2.794273
# ...         ...       ...
# 16379 -3.362360 -2.911199
# 16380  3.156721  2.686386
# 16381 -3.293254  1.155332
# 16382 -0.880720  2.751112
# 16383  0.659138 -2.956421
#
# [16384 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.values[:,:2]
#y = data.values[:,2]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle = False)
X_train, X_test= train_test_split(X, test_size = 0.3, shuffle = False)
plt.scatter(X_train[:,0], X_train[:,1])
plt.scatter(X_train[:,0], X_train[:,1])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=16)
kmeans.fit(X_train)

assignments = kmeans.labels_
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], assignments)
# Out:
# [<matplotlib.lines.Line2D at 0x1d725464d60>,
#  <matplotlib.lines.Line2D at 0x1d725474100>,
#  <matplotlib.lines.Line2D at 0x1d725474460>,
#  <matplotlib.lines.Line2D at 0x1d7254747c0>,
#  <matplotlib.lines.Line2D at 0x1d725474b20>,
#  <matplotlib.lines.Line2D at 0x1d725474e80>,
#  <matplotlib.lines.Line2D at 0x1d72547e250>,
#  <matplotlib.lines.Line2D at 0x1d72547e5e0>,
#  <matplotlib.lines.Line2D at 0x1d72547e970>,
#  <matplotlib.lines.Line2D at 0x1d72547ecd0>,
#  <matplotlib.lines.Line2D at 0x1d72548a070>,
#  <matplotlib.lines.Line2D at 0x1d72548a3d0>,
#  <matplotlib.lines.Line2D at 0x1d72548a730>,
#  <matplotlib.lines.Line2D at 0x1d72548aa90>,
#  <matplotlib.lines.Line2D at 0x1d72548adf0>,
#  <matplotlib.lines.Line2D at 0x1d725495190>]

# %%
y_pred = kmeans.predict(X_train)

# %%
kmeans.labels_
# Out:
# array([ 7, 12,  4, ...,  0,  4,  9])

# %%
y_pred
# Out:
# array([ 7, 12,  4, ...,  0,  4,  9])

# %%
if False in (kmeans.labels_ == y_pred).tolist(): print("One error") 
else: print("No error")
# Out:
# No error
